# %%
import sqlalchemy
import pandas as pd
import yfinance

# %%
wiki = 'https://en.wikipedia.org/wiki/'

# %%
tickersSensex = pd.read_html(wiki+'BSE_SENSEX')[1].Symbol.to_list()
tickerDOW = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1].Symbol.to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14704\2297476034.py in ?()
# ----> 1 tickersSensex = pd.read_html(wiki+'BSE_SENSEX')[1].Symbol.to_list()
#       2 tickerDOW = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1].Symbol.to_list()
#
# c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Symbol'

# %%
import pandas as pd

wiki = 'https://en.wikipedia.org/wiki/'
sensex_df = pd.read_html(wiki+'BSE_SENSEX')[1]
dow_df = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1]

print(sensex_df.head())
print(dow_df.head())
# Out:
#                 0                              1
# 0             NaN                            NaN
# 1      Foundation  1 January 1986 (39 years ago)
# 2        Operator                     Asia Index
# 3       Exchanges                            BSE
# 4  Trading symbol                         ^BSESN
#     0                                                  1
# 0 NaN  This table's "industry" column's factual accur...

# %%
tickersSensex = sensex_df['Ticker'].to_list()
tickerDOW = dow_df['Ticker'].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Ticker'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tickersSensex = sensex_df['Ticker'].to_list()
#       2 tickerDOW = dow_df['Ticker'].to_list()
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Ticker'

# %%
import pandas as pd

wiki = 'https://en.wikipedia.org/wiki/'
sensex_df = pd.read_html(wiki+'BSE_SENSEX')[1]
dow_df = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1]

print(sensex_df.columns)
print(dow_df.columns)
# Out:
# Index([0, 1], dtype='int64')
# Index([0, 1], dtype='int64')

# %%
tickersSensex = sensex_df['correct_column_name'].to_list()
tickerDOW = dow_df['correct_column_name'].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'correct_column_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tickersSensex = sensex_df['correct_column_name'].to_list()
#       2 tickerDOW = dow_df['correct_column_name'].to_list()
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'correct_column_name'

# %%
import pandas as pd

wiki = 'https://en.wikipedia.org/wiki/'
sensex_df = pd.read_html(wiki+'BSE_SENSEX')[1]
dow_df = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1]

print(sensex_df.columns)
print(dow_df.columns)
# Out:
# Index([0, 1], dtype='int64')
# Index([0, 1], dtype='int64')

# %%
tickersSensex = sensex_df['Company'].to_list()
tickerDOW = dow_df['Company'].to_list()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Company'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tickersSensex = sensex_df['Company'].to_list()
#       2 tickerDOW = dow_df['Company'].to_list()
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Company'

# %%
import pandas as pd

wiki = 'https://en.wikipedia.org/wiki/'
sensex_df = pd.read_html(wiki+'BSE_SENSEX')[1]
dow_df = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1]

print("Columns in SENSEX DataFrame:", sensex_df.columns)
print("Columns in DOW DataFrame:", dow_df.columns)
# Out:
# Columns in SENSEX DataFrame: Index([0, 1], dtype='int64')
# Columns in DOW DataFrame: Index([0, 1], dtype='int64')

# %%
sensex_df
# Out:
#                    0                                                  1
# 0                NaN                                                NaN
# 1         Foundation                      1 January 1986 (39 years ago)
# 2           Operator                                         Asia Index
# 3          Exchanges                                                BSE
# 4     Trading symbol                                             ^BSESN
# 5       Constituents                                                 30
# 6               Type                                          Large cap
# 7         Market cap  ₹165.50 lakh crore (US$1.9 trillion) (Septembe...
# 8   Weighting method                   Free-float market capitalisation
# 9    Related indices  .mw-parser-output .plainlist ol,.mw-parser-out...
# 10           Website                                   official website

# %%
wiki = 'https://en.wikipedia.org/wiki/'

# %%
tickersSensex = pd.read_html(wiki+'BSE_SENSEX')[1].Symbol.to_list()
tickerDOW = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1].Symbol.to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14704\2297476034.py in ?()
# ----> 1 tickersSensex = pd.read_html(wiki+'BSE_SENSEX')[1].Symbol.to_list()
#       2 tickerDOW = pd.read_html(wiki+'Dow_Jones_Industrial_Average')[1].Symbol.to_list()
#
# c:\Users\surface\anaconda3\envs\visa\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Symbol'

# %%
def getdata():
    data = []
    for ticker in tickers:
        data.append(yf.download(ticker).reset_index())
    
    return data

india, US = getdata(tickersSensex), getdata(tickerDOW)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 8
#       4         data.append(yf.download(ticker).reset_index())
#       6     return data
# ----> 8 india, US = getdata(tickersSensex), getdata(tickerDOW)
#
# NameError: name 'tickersSensex' is not defined
